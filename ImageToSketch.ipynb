# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# Out:
# C:\Users\prajwal meshram\AppData\Local\Temp\ipykernel_21812\3412576163.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
img = cv2.imread("C:\\Users\\prajwal meshram\\Pictures\\Camera Roll\\sketch.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,8))
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,8))
plt.imshow(img_gray,cmap="gray")

# %%
img_invert = cv2.bitwise_not(img_gray)
plt.figure(figsize=(10,8))
plt.imshow(img_invert,cmap="gray")

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(10,8))
plt.imshow(img_smoothing,cmap="gray")
# Out:
# (-0.5, 959.5, 1279.5, -0.5)

# %%
final = cv2.divide(img_gray, 255 - img_smoothing, scale=220)
plt.figure(figsize=(10,8))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()
